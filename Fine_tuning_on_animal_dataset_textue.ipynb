# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaBelenCarbajal/Thesis-Experiment-3/blob/main/Fine_tuning_on_animal_dataset_textue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataset animal shapes**
#
# 1) installing packages

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install osculari
# Out:
# Collecting osculari
#   Downloading osculari-0.0.4-py3-none-any.whl (34 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from osculari) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from osculari) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from osculari) (0.18.0+cu121)
# Collecting clip-openai (from osculari)
#   Downloading clip_openai-1.0.post20230121-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.8 MB/s eta 0:00:00
# Collecting visualpriors (from osculari)
#   Downloading visualpriors-0.3.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from osculari) (4.8.0.76)
# Collecting ftfy (from clip-openai->osculari)
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip-openai->osculari) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip-openai->osculari) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->osculari) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->osculari) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->osculari) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->osculari) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->osculari) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->osculari) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->osculari)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->osculari)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->osculari)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->osculari)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->osculari)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->osculari)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->osculari)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->osculari)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->osculari)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->osculari)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->osculari)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->osculari) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->osculari)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 61.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->osculari) (9.4.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip-openai->osculari) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->osculari) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->osculari) (1.3.0)
# Building wheels for collected packages: visualpriors
#   Building wheel for visualpriors (setup.py) ... done
#   Created wheel for visualpriors: filename=visualpriors-0.3.5-py3-none-any.whl size=11368 sha256=6b88b42818ec5d4d911bf53ac7cb8bcb0cdfe25c48664b9d8c9d64a56036e743
#   Stored in directory: /root/.cache/pip/wheels/ce/18/2b/ac0e173977d8a72ea7155168fbaa891e5e8e4cafa01957cba3
# Successfully built visualpriors
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ftfy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, visualpriors, clip-openai, osculari
# Successfully installed clip-openai-1.0.post20230121 ftfy-6.2.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 osculari-0.0.4 visualpriors-0.3.5

# %%
# importing required packages
import osculari

import numpy as np
from matplotlib import pyplot as plt
import torch
import os
from random import choice
import pandas as pd

from torchvision.datasets import ImageFolder
from torchvision.io import read_image, ImageReadMode
from torch.utils.data import Dataset
import torchvision.transforms.functional as transform
from torchvision import transforms
from torchvision.transforms import v2
from torchvision.transforms import Pad
from torch.utils.data import DataLoader
import cv2

from PIL import Image

# %% [markdown]
# 2) I uploaded images180.zip to this collab, it needs to be unzipped

# %%
# unzip folder (previously uploaded in collab)
# !unzip images180.zip -d my_data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: my_data/images180/images224/horse/88.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._88.png
#   inflating: my_data/images180/images224/horse/77.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._77.png
#   inflating: my_data/images180/images224/horse/63.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._63.png
#   inflating: my_data/images180/images224/horse/62.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._62.png
#   inflating: my_data/images180/images224/horse/76.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._76.png
#   inflating: my_data/images180/images224/horse/89.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._89.png
#   inflating: my_data/images180/images224/horse/60.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._60.png
#   inflating: my_data/images180/images224/horse/74.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._74.png
#   inflating: my_data/images180/images224/horse/48.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._48.png
#   inflating: my_data/images180/images224/horse/49.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._49.png
#   inflating: my_data/images180/images224/horse/75.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._75.png
#   inflating: my_data/images180/images224/horse/61.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._61.png
#   inflating: my_data/images180/images224/horse/59.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._59.png
#   inflating: my_data/images180/images224/horse/65.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._65.png
#   inflating: my_data/images180/images224/horse/71.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._71.png
#   inflating: my_data/images180/images224/horse/70.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._70.png
#   inflating: my_data/images180/images224/horse/64.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._64.png
#   inflating: my_data/images180/images224/horse/58.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._58.png
#   inflating: my_data/images180/images224/horse/99.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._99.png
#   inflating: my_data/images180/images224/horse/8.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._8.png
#   inflating: my_data/images180/images224/horse/72.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._72.png
#   inflating: my_data/images180/images224/horse/66.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._66.png
#   inflating: my_data/images180/images224/horse/67.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._67.png
#   inflating: my_data/images180/images224/horse/73.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._73.png
#   inflating: my_data/images180/images224/horse/9.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._9.png
#   inflating: my_data/images180/images224/horse/98.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._98.png
#   inflating: my_data/images180/images224/horse/14.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._14.png
#   inflating: my_data/images180/images224/horse/28.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._28.png
#   inflating: my_data/images180/images224/horse/29.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._29.png
#   inflating: my_data/images180/images224/horse/15.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._15.png
#   inflating: my_data/images180/images224/horse/100.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._100.png
#   inflating: my_data/images180/images224/horse/17.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._17.png
#   inflating: my_data/images180/images224/horse/16.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._16.png
#   inflating: my_data/images180/images224/horse/12.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._12.png
#   inflating: my_data/images180/images224/horse/13.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._13.png
#   inflating: my_data/images180/images224/horse/39.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._39.png
#   inflating: my_data/images180/images224/horse/11.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._11.png
#   inflating: my_data/images180/images224/horse/10.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._10.png
#   inflating: my_data/images180/images224/horse/38.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._38.png
#   inflating: my_data/images180/images224/horse/35.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._35.png
#   inflating: my_data/images180/images224/horse/21.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._21.png
#   inflating: my_data/images180/images224/horse/20.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._20.png
#   inflating: my_data/images180/images224/horse/34.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._34.png
#   inflating: my_data/images180/images224/horse/22.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._22.png
#   inflating: my_data/images180/images224/horse/36.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._36.png
#   inflating: my_data/images180/images224/horse/37.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._37.png
#   inflating: my_data/images180/images224/horse/23.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._23.png
#   inflating: my_data/images180/images224/horse/27.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._27.png
#   inflating: my_data/images180/images224/horse/33.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._33.png
#   inflating: my_data/images180/images224/horse/32.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._32.png
#   inflating: my_data/images180/images224/horse/26.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._26.png
#   inflating: my_data/images180/images224/horse/18.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._18.png
#   inflating: my_data/images180/images224/horse/30.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._30.png
#   inflating: my_data/images180/images224/horse/24.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._24.png
#   inflating: my_data/images180/images224/horse/25.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._25.png
#   inflating: my_data/images180/images224/horse/31.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._31.png
#   inflating: my_data/images180/images224/horse/19.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._19.png
#   inflating: my_data/images180/images224/horse/95.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._95.png
#   inflating: my_data/images180/images224/horse/81.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._81.png
#   inflating: my_data/images180/images224/horse/4.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._4.png
#   inflating: my_data/images180/images224/horse/56.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._56.png
#   inflating: my_data/images180/images224/horse/42.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._42.png
#   inflating: my_data/images180/images224/horse/43.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._43.png
#   inflating: my_data/images180/images224/horse/5.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._5.png
#   inflating: my_data/images180/images224/horse/57.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._57.png
#   inflating: my_data/images180/images224/horse/80.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._80.png
#   inflating: my_data/images180/images224/horse/94.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._94.png
#   inflating: my_data/images180/images224/horse/82.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._82.png
#   inflating: my_data/images180/images224/horse/96.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._96.png
#   inflating: my_data/images180/images224/horse/41.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._41.png
#   inflating: my_data/images180/images224/horse/55.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._55.png
#   inflating: my_data/images180/images224/horse/7.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._7.png
#   inflating: my_data/images180/images224/horse/69.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._69.png
#   inflating: my_data/images180/images224/horse/68.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._68.png
#   inflating: my_data/images180/images224/horse/54.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._54.png
#   inflating: my_data/images180/images224/horse/6.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._6.png
#   inflating: my_data/images180/images224/horse/40.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._40.png
#   inflating: my_data/images180/images224/horse/97.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._97.png
#   inflating: my_data/images180/images224/horse/83.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._83.png
#   inflating: my_data/images180/images224/horse/87.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._87.png
#   inflating: my_data/images180/images224/horse/93.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._93.png
#   inflating: my_data/images180/images224/horse/78.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._78.png
#   inflating: my_data/images180/images224/horse/44.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._44.png
#   inflating: my_data/images180/images224/horse/2.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._2.png
#   inflating: my_data/images180/images224/horse/50.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._50.png
#   inflating: my_data/images180/images224/horse/3.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._3.png
#   inflating: my_data/images180/images224/horse/51.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._51.png
#   inflating: my_data/images180/images224/horse/45.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._45.png
#   inflating: my_data/images180/images224/horse/79.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._79.png
#   inflating: my_data/images180/images224/horse/92.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._92.png
#   inflating: my_data/images180/images224/horse/86.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._86.png
#   inflating: my_data/images180/images224/horse/90.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._90.png
#   inflating: my_data/images180/images224/horse/84.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._84.png
#   inflating: my_data/images180/images224/horse/53.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._53.png
#   inflating: my_data/images180/images224/horse/1.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._1.png
#   inflating: my_data/images180/images224/horse/47.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._47.png
#   inflating: my_data/images180/images224/horse/46.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._46.png
#   inflating: my_data/images180/images224/horse/52.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._52.png
#   inflating: my_data/images180/images224/horse/85.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._85.png
#   inflating: my_data/images180/images224/horse/91.png
#   inflating: my_data/__MACOSX/images180/images224/horse/._91.png
#   inflating: my_data/images180/images224/fish/88.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._88.png
#   inflating: my_data/images180/images224/fish/77.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._77.png
#   inflating: my_data/images180/images224/fish/63.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._63.png
#   inflating: my_data/images180/images224/fish/62.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._62.png
#   inflating: my_data/images180/images224/fish/76.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._76.png
#   inflating: my_data/images180/images224/fish/89.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._89.png
#   inflating: my_data/images180/images224/fish/60.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._60.png
#   inflating: my_data/images180/images224/fish/74.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._74.png
#   inflating: my_data/images180/images224/fish/48.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._48.png
#   inflating: my_data/images180/images224/fish/49.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._49.png
#   inflating: my_data/images180/images224/fish/75.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._75.png
#   inflating: my_data/images180/images224/fish/61.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._61.png
#   inflating: my_data/images180/images224/fish/59.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._59.png
#   inflating: my_data/images180/images224/fish/65.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._65.png
#   inflating: my_data/images180/images224/fish/71.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._71.png
#   inflating: my_data/images180/images224/fish/70.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._70.png
#   inflating: my_data/images180/images224/fish/64.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._64.png
#   inflating: my_data/images180/images224/fish/58.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._58.png
#   inflating: my_data/images180/images224/fish/99.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._99.png
#   inflating: my_data/images180/images224/fish/8.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._8.png
#   inflating: my_data/images180/images224/fish/72.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._72.png
#   inflating: my_data/images180/images224/fish/66.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._66.png
#   inflating: my_data/images180/images224/fish/67.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._67.png
#   inflating: my_data/images180/images224/fish/73.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._73.png
#   inflating: my_data/images180/images224/fish/9.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._9.png
#   inflating: my_data/images180/images224/fish/98.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._98.png
#   inflating: my_data/images180/images224/fish/14.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._14.png
#   inflating: my_data/images180/images224/fish/28.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._28.png
#   inflating: my_data/images180/images224/fish/29.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._29.png
#   inflating: my_data/images180/images224/fish/15.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._15.png
#   inflating: my_data/images180/images224/fish/100.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._100.png
#   inflating: my_data/images180/images224/fish/17.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._17.png
#   inflating: my_data/images180/images224/fish/16.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._16.png
#   inflating: my_data/images180/images224/fish/12.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._12.png
#   inflating: my_data/images180/images224/fish/13.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._13.png
#   inflating: my_data/images180/images224/fish/39.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._39.png
#   inflating: my_data/images180/images224/fish/11.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._11.png
#   inflating: my_data/images180/images224/fish/10.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._10.png
#   inflating: my_data/images180/images224/fish/38.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._38.png
#   inflating: my_data/images180/images224/fish/35.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._35.png
#   inflating: my_data/images180/images224/fish/21.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._21.png
#   inflating: my_data/images180/images224/fish/20.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._20.png
#   inflating: my_data/images180/images224/fish/34.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._34.png
#   inflating: my_data/images180/images224/fish/22.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._22.png
#   inflating: my_data/images180/images224/fish/36.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._36.png
#   inflating: my_data/images180/images224/fish/37.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._37.png
#   inflating: my_data/images180/images224/fish/23.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._23.png
#   inflating: my_data/images180/images224/fish/27.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._27.png
#   inflating: my_data/images180/images224/fish/33.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._33.png
#   inflating: my_data/images180/images224/fish/32.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._32.png
#   inflating: my_data/images180/images224/fish/26.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._26.png
#   inflating: my_data/images180/images224/fish/18.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._18.png
#   inflating: my_data/images180/images224/fish/30.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._30.png
#   inflating: my_data/images180/images224/fish/24.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._24.png
#   inflating: my_data/images180/images224/fish/25.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._25.png
#   inflating: my_data/images180/images224/fish/31.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._31.png
#   inflating: my_data/images180/images224/fish/19.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._19.png
#   inflating: my_data/images180/images224/fish/95.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._95.png
#   inflating: my_data/images180/images224/fish/81.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._81.png
#   inflating: my_data/images180/images224/fish/4.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._4.png
#   inflating: my_data/images180/images224/fish/56.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._56.png
#   inflating: my_data/images180/images224/fish/42.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._42.png
#   inflating: my_data/images180/images224/fish/43.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._43.png
#   inflating: my_data/images180/images224/fish/5.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._5.png
#   inflating: my_data/images180/images224/fish/57.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._57.png
#   inflating: my_data/images180/images224/fish/80.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._80.png
#   inflating: my_data/images180/images224/fish/94.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._94.png
#   inflating: my_data/images180/images224/fish/82.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._82.png
#   inflating: my_data/images180/images224/fish/96.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._96.png
#   inflating: my_data/images180/images224/fish/41.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._41.png
#   inflating: my_data/images180/images224/fish/55.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._55.png
#   inflating: my_data/images180/images224/fish/7.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._7.png
#   inflating: my_data/images180/images224/fish/69.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._69.png
#   inflating: my_data/images180/images224/fish/68.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._68.png
#   inflating: my_data/images180/images224/fish/54.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._54.png
#   inflating: my_data/images180/images224/fish/6.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._6.png
#   inflating: my_data/images180/images224/fish/40.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._40.png
#   inflating: my_data/images180/images224/fish/97.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._97.png
#   inflating: my_data/images180/images224/fish/83.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._83.png
#   inflating: my_data/images180/images224/fish/87.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._87.png
#   inflating: my_data/images180/images224/fish/93.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._93.png
#   inflating: my_data/images180/images224/fish/78.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._78.png
#   inflating: my_data/images180/images224/fish/44.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._44.png
#   inflating: my_data/images180/images224/fish/2.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._2.png
#   inflating: my_data/images180/images224/fish/50.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._50.png
#   inflating: my_data/images180/images224/fish/3.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._3.png
#   inflating: my_data/images180/images224/fish/51.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._51.png
#   inflating: my_data/images180/images224/fish/45.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._45.png
#   inflating: my_data/images180/images224/fish/79.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._79.png
#   inflating: my_data/images180/images224/fish/92.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._92.png
#   inflating: my_data/images180/images224/fish/86.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._86.png
#   inflating: my_data/images180/images224/fish/90.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._90.png
#   inflating: my_data/images180/images224/fish/84.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._84.png
#   inflating: my_data/images180/images224/fish/53.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._53.png
#   inflating: my_data/images180/images224/fish/1.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._1.png
#   inflating: my_data/images180/images224/fish/47.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._47.png
#   inflating: my_data/images180/images224/fish/46.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._46.png
#   inflating: my_data/images180/images224/fish/52.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._52.png
#   inflating: my_data/images180/images224/fish/85.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._85.png
#   inflating: my_data/images180/images224/fish/91.png
#   inflating: my_data/__MACOSX/images180/images224/fish/._91.png
#   inflating: my_data/images180/images224/cow/88.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._88.png
#   inflating: my_data/images180/images224/cow/77.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._77.png
#   inflating: my_data/images180/images224/cow/63.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._63.png
#   inflating: my_data/images180/images224/cow/62.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._62.png
#   inflating: my_data/images180/images224/cow/76.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._76.png
#   inflating: my_data/images180/images224/cow/89.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._89.png
#   inflating: my_data/images180/images224/cow/60.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._60.png
#   inflating: my_data/images180/images224/cow/74.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._74.png
#   inflating: my_data/images180/images224/cow/48.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._48.png
#   inflating: my_data/images180/images224/cow/49.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._49.png
#   inflating: my_data/images180/images224/cow/75.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._75.png
#   inflating: my_data/images180/images224/cow/61.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._61.png
#   inflating: my_data/images180/images224/cow/59.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._59.png
#   inflating: my_data/images180/images224/cow/65.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._65.png
#   inflating: my_data/images180/images224/cow/71.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._71.png
#   inflating: my_data/images180/images224/cow/70.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._70.png
#   inflating: my_data/images180/images224/cow/64.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._64.png
#   inflating: my_data/images180/images224/cow/58.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._58.png
#   inflating: my_data/images180/images224/cow/99.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._99.png
#   inflating: my_data/images180/images224/cow/8.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._8.png
#   inflating: my_data/images180/images224/cow/72.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._72.png
#   inflating: my_data/images180/images224/cow/66.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._66.png
#   inflating: my_data/images180/images224/cow/67.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._67.png
#   inflating: my_data/images180/images224/cow/73.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._73.png
#   inflating: my_data/images180/images224/cow/9.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._9.png
#   inflating: my_data/images180/images224/cow/98.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._98.png
#   inflating: my_data/images180/images224/cow/14.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._14.png
#   inflating: my_data/images180/images224/cow/28.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._28.png
#   inflating: my_data/images180/images224/cow/29.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._29.png
#   inflating: my_data/images180/images224/cow/15.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._15.png
#   inflating: my_data/images180/images224/cow/100.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._100.png
#   inflating: my_data/images180/images224/cow/17.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._17.png
#   inflating: my_data/images180/images224/cow/16.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._16.png
#   inflating: my_data/images180/images224/cow/12.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._12.png
#   inflating: my_data/images180/images224/cow/13.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._13.png
#   inflating: my_data/images180/images224/cow/39.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._39.png
#   inflating: my_data/images180/images224/cow/11.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._11.png
#   inflating: my_data/images180/images224/cow/10.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._10.png
#   inflating: my_data/images180/images224/cow/38.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._38.png
#   inflating: my_data/images180/images224/cow/35.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._35.png
#   inflating: my_data/images180/images224/cow/21.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._21.png
#   inflating: my_data/images180/images224/cow/20.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._20.png
#   inflating: my_data/images180/images224/cow/34.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._34.png
#   inflating: my_data/images180/images224/cow/22.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._22.png
#   inflating: my_data/images180/images224/cow/36.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._36.png
#   inflating: my_data/images180/images224/cow/37.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._37.png
#   inflating: my_data/images180/images224/cow/23.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._23.png
#   inflating: my_data/images180/images224/cow/27.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._27.png
#   inflating: my_data/images180/images224/cow/33.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._33.png
#   inflating: my_data/images180/images224/cow/32.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._32.png
#   inflating: my_data/images180/images224/cow/26.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._26.png
#   inflating: my_data/images180/images224/cow/18.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._18.png
#   inflating: my_data/images180/images224/cow/30.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._30.png
#   inflating: my_data/images180/images224/cow/24.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._24.png
#   inflating: my_data/images180/images224/cow/25.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._25.png
#   inflating: my_data/images180/images224/cow/31.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._31.png
#   inflating: my_data/images180/images224/cow/19.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._19.png
#   inflating: my_data/images180/images224/cow/95.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._95.png
#   inflating: my_data/images180/images224/cow/81.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._81.png
#   inflating: my_data/images180/images224/cow/4.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._4.png
#   inflating: my_data/images180/images224/cow/56.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._56.png
#   inflating: my_data/images180/images224/cow/42.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._42.png
#   inflating: my_data/images180/images224/cow/43.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._43.png
#   inflating: my_data/images180/images224/cow/5.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._5.png
#   inflating: my_data/images180/images224/cow/57.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._57.png
#   inflating: my_data/images180/images224/cow/80.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._80.png
#   inflating: my_data/images180/images224/cow/94.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._94.png
#   inflating: my_data/images180/images224/cow/82.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._82.png
#   inflating: my_data/images180/images224/cow/96.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._96.png
#   inflating: my_data/images180/images224/cow/41.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._41.png
#   inflating: my_data/images180/images224/cow/55.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._55.png
#   inflating: my_data/images180/images224/cow/7.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._7.png
#   inflating: my_data/images180/images224/cow/69.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._69.png
#   inflating: my_data/images180/images224/cow/68.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._68.png
#   inflating: my_data/images180/images224/cow/54.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._54.png
#   inflating: my_data/images180/images224/cow/6.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._6.png
#   inflating: my_data/images180/images224/cow/40.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._40.png
#   inflating: my_data/images180/images224/cow/97.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._97.png
#   inflating: my_data/images180/images224/cow/83.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._83.png
#   inflating: my_data/images180/images224/cow/87.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._87.png
#   inflating: my_data/images180/images224/cow/93.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._93.png
#   inflating: my_data/images180/images224/cow/78.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._78.png
#   inflating: my_data/images180/images224/cow/44.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._44.png
#   inflating: my_data/images180/images224/cow/2.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._2.png
#   inflating: my_data/images180/images224/cow/50.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._50.png
#   inflating: my_data/images180/images224/cow/3.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._3.png
#   inflating: my_data/images180/images224/cow/51.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._51.png
#   inflating: my_data/images180/images224/cow/45.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._45.png
#   inflating: my_data/images180/images224/cow/79.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._79.png
#   inflating: my_data/images180/images224/cow/92.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._92.png
#   inflating: my_data/images180/images224/cow/86.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._86.png
#   inflating: my_data/images180/images224/cow/90.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._90.png
#   inflating: my_data/images180/images224/cow/84.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._84.png
#   inflating: my_data/images180/images224/cow/53.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._53.png
#   inflating: my_data/images180/images224/cow/1.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._1.png
#   inflating: my_data/images180/images224/cow/47.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._47.png
#   inflating: my_data/images180/images224/cow/46.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._46.png
#   inflating: my_data/images180/images224/cow/52.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._52.png
#   inflating: my_data/images180/images224/cow/85.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._85.png
#   inflating: my_data/images180/images224/cow/91.png
#   inflating: my_data/__MACOSX/images180/images224/cow/._91.png
#   inflating: my_data/images180/images224/deer/88.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._88.png
#   inflating: my_data/images180/images224/deer/77.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._77.png
#   inflating: my_data/images180/images224/deer/63.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._63.png
#   inflating: my_data/images180/images224/deer/62.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._62.png
#   inflating: my_data/images180/images224/deer/76.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._76.png
#   inflating: my_data/images180/images224/deer/89.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._89.png
#   inflating: my_data/images180/images224/deer/60.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._60.png
#   inflating: my_data/images180/images224/deer/74.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._74.png
#   inflating: my_data/images180/images224/deer/48.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._48.png
#   inflating: my_data/images180/images224/deer/49.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._49.png
#   inflating: my_data/images180/images224/deer/75.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._75.png
#   inflating: my_data/images180/images224/deer/61.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._61.png
#   inflating: my_data/images180/images224/deer/59.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._59.png
#   inflating: my_data/images180/images224/deer/65.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._65.png
#   inflating: my_data/images180/images224/deer/71.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._71.png
#   inflating: my_data/images180/images224/deer/70.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._70.png
#   inflating: my_data/images180/images224/deer/64.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._64.png
#   inflating: my_data/images180/images224/deer/58.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._58.png
#   inflating: my_data/images180/images224/deer/99.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._99.png
#   inflating: my_data/images180/images224/deer/8.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._8.png
#   inflating: my_data/images180/images224/deer/72.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._72.png
#   inflating: my_data/images180/images224/deer/66.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._66.png
#   inflating: my_data/images180/images224/deer/67.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._67.png
#   inflating: my_data/images180/images224/deer/73.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._73.png
#   inflating: my_data/images180/images224/deer/9.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._9.png
#   inflating: my_data/images180/images224/deer/98.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._98.png
#   inflating: my_data/images180/images224/deer/14.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._14.png
#   inflating: my_data/images180/images224/deer/28.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._28.png
#   inflating: my_data/images180/images224/deer/29.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._29.png
#   inflating: my_data/images180/images224/deer/15.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._15.png
#   inflating: my_data/images180/images224/deer/100.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._100.png
#   inflating: my_data/images180/images224/deer/17.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._17.png
#   inflating: my_data/images180/images224/deer/16.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._16.png
#   inflating: my_data/images180/images224/deer/12.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._12.png
#   inflating: my_data/images180/images224/deer/13.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._13.png
#   inflating: my_data/images180/images224/deer/39.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._39.png
#   inflating: my_data/images180/images224/deer/11.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._11.png
#   inflating: my_data/images180/images224/deer/10.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._10.png
#   inflating: my_data/images180/images224/deer/38.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._38.png
#   inflating: my_data/images180/images224/deer/35.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._35.png
#   inflating: my_data/images180/images224/deer/21.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._21.png
#   inflating: my_data/images180/images224/deer/20.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._20.png
#   inflating: my_data/images180/images224/deer/34.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._34.png
#   inflating: my_data/images180/images224/deer/22.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._22.png
#   inflating: my_data/images180/images224/deer/36.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._36.png
#   inflating: my_data/images180/images224/deer/37.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._37.png
#   inflating: my_data/images180/images224/deer/23.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._23.png
#   inflating: my_data/images180/images224/deer/27.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._27.png
#   inflating: my_data/images180/images224/deer/33.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._33.png
#   inflating: my_data/images180/images224/deer/32.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._32.png
#   inflating: my_data/images180/images224/deer/26.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._26.png
#   inflating: my_data/images180/images224/deer/18.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._18.png
#   inflating: my_data/images180/images224/deer/30.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._30.png
#   inflating: my_data/images180/images224/deer/24.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._24.png
#   inflating: my_data/images180/images224/deer/25.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._25.png
#   inflating: my_data/images180/images224/deer/31.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._31.png
#   inflating: my_data/images180/images224/deer/19.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._19.png
#   inflating: my_data/images180/images224/deer/95.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._95.png
#   inflating: my_data/images180/images224/deer/81.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._81.png
#   inflating: my_data/images180/images224/deer/4.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._4.png
#   inflating: my_data/images180/images224/deer/56.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._56.png
#   inflating: my_data/images180/images224/deer/42.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._42.png
#   inflating: my_data/images180/images224/deer/43.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._43.png
#   inflating: my_data/images180/images224/deer/5.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._5.png
#   inflating: my_data/images180/images224/deer/57.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._57.png
#   inflating: my_data/images180/images224/deer/80.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._80.png
#   inflating: my_data/images180/images224/deer/94.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._94.png
#   inflating: my_data/images180/images224/deer/82.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._82.png
#   inflating: my_data/images180/images224/deer/96.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._96.png
#   inflating: my_data/images180/images224/deer/41.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._41.png
#   inflating: my_data/images180/images224/deer/55.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._55.png
#   inflating: my_data/images180/images224/deer/7.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._7.png
#   inflating: my_data/images180/images224/deer/69.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._69.png
#   inflating: my_data/images180/images224/deer/68.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._68.png
#   inflating: my_data/images180/images224/deer/54.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._54.png
#   inflating: my_data/images180/images224/deer/6.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._6.png
#   inflating: my_data/images180/images224/deer/40.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._40.png
#   inflating: my_data/images180/images224/deer/97.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._97.png
#   inflating: my_data/images180/images224/deer/83.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._83.png
#   inflating: my_data/images180/images224/deer/87.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._87.png
#   inflating: my_data/images180/images224/deer/93.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._93.png
#   inflating: my_data/images180/images224/deer/78.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._78.png
#   inflating: my_data/images180/images224/deer/44.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._44.png
#   inflating: my_data/images180/images224/deer/2.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._2.png
#   inflating: my_data/images180/images224/deer/50.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._50.png
#   inflating: my_data/images180/images224/deer/3.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._3.png
#   inflating: my_data/images180/images224/deer/51.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._51.png
#   inflating: my_data/images180/images224/deer/45.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._45.png
#   inflating: my_data/images180/images224/deer/79.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._79.png
#   inflating: my_data/images180/images224/deer/92.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._92.png
#   inflating: my_data/images180/images224/deer/86.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._86.png
#   inflating: my_data/images180/images224/deer/90.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._90.png
#   inflating: my_data/images180/images224/deer/84.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._84.png
#   inflating: my_data/images180/images224/deer/53.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._53.png
#   inflating: my_data/images180/images224/deer/1.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._1.png
#   inflating: my_data/images180/images224/deer/47.png
#   inflating: my_data/__MACOSX/images180/images224/deer/._47.png
#   inflating: my_data/images180/images224/deer/46.png
# ...
#   inflating: my_data/images180/images180/tortoise/40.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._40.png
#   inflating: my_data/images180/images180/tortoise/97.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._97.png
#   inflating: my_data/images180/images180/tortoise/83.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._83.png
#   inflating: my_data/images180/images180/tortoise/87.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._87.png
#   inflating: my_data/images180/images180/tortoise/93.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._93.png
#   inflating: my_data/images180/images180/tortoise/78.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._78.png
#   inflating: my_data/images180/images180/tortoise/44.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._44.png
#   inflating: my_data/images180/images180/tortoise/2.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._2.png
#   inflating: my_data/images180/images180/tortoise/50.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._50.png
#   inflating: my_data/images180/images180/tortoise/3.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._3.png
#   inflating: my_data/images180/images180/tortoise/51.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._51.png
#   inflating: my_data/images180/images180/tortoise/45.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._45.png
#   inflating: my_data/images180/images180/tortoise/79.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._79.png
#   inflating: my_data/images180/images180/tortoise/92.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._92.png
#   inflating: my_data/images180/images180/tortoise/86.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._86.png
#   inflating: my_data/images180/images180/tortoise/90.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._90.png
#   inflating: my_data/images180/images180/tortoise/84.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._84.png
#   inflating: my_data/images180/images180/tortoise/53.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._53.png
#   inflating: my_data/images180/images180/tortoise/1.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._1.png
#   inflating: my_data/images180/images180/tortoise/47.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._47.png
#   inflating: my_data/images180/images180/tortoise/46.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._46.png
#   inflating: my_data/images180/images180/tortoise/52.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._52.png
#   inflating: my_data/images180/images180/tortoise/85.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._85.png
#   inflating: my_data/images180/images180/tortoise/91.png
#   inflating: my_data/__MACOSX/images180/images180/tortoise/._91.png
#   inflating: my_data/images180/images180/elephant/88.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._88.png
#   inflating: my_data/images180/images180/elephant/77.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._77.png
#   inflating: my_data/images180/images180/elephant/63.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._63.png
#   inflating: my_data/images180/images180/elephant/62.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._62.png
#   inflating: my_data/images180/images180/elephant/76.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._76.png
#   inflating: my_data/images180/images180/elephant/89.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._89.png
#   inflating: my_data/images180/images180/elephant/60.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._60.png
#   inflating: my_data/images180/images180/elephant/74.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._74.png
#   inflating: my_data/images180/images180/elephant/48.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._48.png
#   inflating: my_data/images180/images180/elephant/49.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._49.png
#   inflating: my_data/images180/images180/elephant/75.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._75.png
#   inflating: my_data/images180/images180/elephant/61.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._61.png
#   inflating: my_data/images180/images180/elephant/59.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._59.png
#   inflating: my_data/images180/images180/elephant/65.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._65.png
#   inflating: my_data/images180/images180/elephant/71.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._71.png
#   inflating: my_data/images180/images180/elephant/70.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._70.png
#   inflating: my_data/images180/images180/elephant/64.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._64.png
#   inflating: my_data/images180/images180/elephant/58.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._58.png
#   inflating: my_data/images180/images180/elephant/99.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._99.png
#   inflating: my_data/images180/images180/elephant/8.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._8.png
#   inflating: my_data/images180/images180/elephant/72.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._72.png
#   inflating: my_data/images180/images180/elephant/66.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._66.png
#   inflating: my_data/images180/images180/elephant/67.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._67.png
#   inflating: my_data/images180/images180/elephant/73.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._73.png
#   inflating: my_data/images180/images180/elephant/9.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._9.png
#   inflating: my_data/images180/images180/elephant/98.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._98.png
#   inflating: my_data/images180/images180/elephant/14.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._14.png
#   inflating: my_data/images180/images180/elephant/28.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._28.png
#   inflating: my_data/images180/images180/elephant/29.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._29.png
#   inflating: my_data/images180/images180/elephant/15.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._15.png
#   inflating: my_data/images180/images180/elephant/100.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._100.png
#   inflating: my_data/images180/images180/elephant/17.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._17.png
#   inflating: my_data/images180/images180/elephant/16.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._16.png
#   inflating: my_data/images180/images180/elephant/12.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._12.png
#   inflating: my_data/images180/images180/elephant/13.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._13.png
#   inflating: my_data/images180/images180/elephant/39.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._39.png
#   inflating: my_data/images180/images180/elephant/11.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._11.png
#   inflating: my_data/images180/images180/elephant/10.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._10.png
#   inflating: my_data/images180/images180/elephant/38.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._38.png
#   inflating: my_data/images180/images180/elephant/35.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._35.png
#   inflating: my_data/images180/images180/elephant/21.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._21.png
#   inflating: my_data/images180/images180/elephant/20.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._20.png
#   inflating: my_data/images180/images180/elephant/34.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._34.png
#   inflating: my_data/images180/images180/elephant/22.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._22.png
#   inflating: my_data/images180/images180/elephant/36.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._36.png
#   inflating: my_data/images180/images180/elephant/37.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._37.png
#   inflating: my_data/images180/images180/elephant/23.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._23.png
#   inflating: my_data/images180/images180/elephant/27.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._27.png
#   inflating: my_data/images180/images180/elephant/33.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._33.png
#   inflating: my_data/images180/images180/elephant/32.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._32.png
#   inflating: my_data/images180/images180/elephant/26.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._26.png
#   inflating: my_data/images180/images180/elephant/18.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._18.png
#   inflating: my_data/images180/images180/elephant/30.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._30.png
#   inflating: my_data/images180/images180/elephant/24.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._24.png
#   inflating: my_data/images180/images180/elephant/25.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._25.png
#   inflating: my_data/images180/images180/elephant/31.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._31.png
#   inflating: my_data/images180/images180/elephant/19.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._19.png
#   inflating: my_data/images180/images180/elephant/95.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._95.png
#   inflating: my_data/images180/images180/elephant/81.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._81.png
#   inflating: my_data/images180/images180/elephant/4.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._4.png
#   inflating: my_data/images180/images180/elephant/56.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._56.png
#   inflating: my_data/images180/images180/elephant/42.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._42.png
#   inflating: my_data/images180/images180/elephant/43.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._43.png
#   inflating: my_data/images180/images180/elephant/5.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._5.png
#   inflating: my_data/images180/images180/elephant/57.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._57.png
#   inflating: my_data/images180/images180/elephant/80.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._80.png
#   inflating: my_data/images180/images180/elephant/94.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._94.png
#   inflating: my_data/images180/images180/elephant/82.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._82.png
#   inflating: my_data/images180/images180/elephant/96.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._96.png
#   inflating: my_data/images180/images180/elephant/41.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._41.png
#   inflating: my_data/images180/images180/elephant/55.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._55.png
#   inflating: my_data/images180/images180/elephant/7.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._7.png
#   inflating: my_data/images180/images180/elephant/69.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._69.png
#   inflating: my_data/images180/images180/elephant/68.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._68.png
#   inflating: my_data/images180/images180/elephant/54.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._54.png
#   inflating: my_data/images180/images180/elephant/6.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._6.png
#   inflating: my_data/images180/images180/elephant/40.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._40.png
#   inflating: my_data/images180/images180/elephant/97.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._97.png
#   inflating: my_data/images180/images180/elephant/83.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._83.png
#   inflating: my_data/images180/images180/elephant/87.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._87.png
#   inflating: my_data/images180/images180/elephant/93.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._93.png
#   inflating: my_data/images180/images180/elephant/78.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._78.png
#   inflating: my_data/images180/images180/elephant/44.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._44.png
#   inflating: my_data/images180/images180/elephant/2.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._2.png
#   inflating: my_data/images180/images180/elephant/50.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._50.png
#   inflating: my_data/images180/images180/elephant/3.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._3.png
#   inflating: my_data/images180/images180/elephant/51.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._51.png
#   inflating: my_data/images180/images180/elephant/45.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._45.png
#   inflating: my_data/images180/images180/elephant/79.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._79.png
#   inflating: my_data/images180/images180/elephant/92.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._92.png
#   inflating: my_data/images180/images180/elephant/86.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._86.png
#   inflating: my_data/images180/images180/elephant/90.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._90.png
#   inflating: my_data/images180/images180/elephant/84.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._84.png
#   inflating: my_data/images180/images180/elephant/53.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._53.png
#   inflating: my_data/images180/images180/elephant/1.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._1.png
#   inflating: my_data/images180/images180/elephant/47.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._47.png
#   inflating: my_data/images180/images180/elephant/46.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._46.png
#   inflating: my_data/images180/images180/elephant/52.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._52.png
#   inflating: my_data/images180/images180/elephant/85.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._85.png
#   inflating: my_data/images180/images180/elephant/91.png
#   inflating: my_data/__MACOSX/images180/images180/elephant/._91.png

# %% [markdown]
# 3) Root: directory to the filder containing the aniam categories

# %%
# root directory to data
root = "my_data/images180/images180/"

# %% [markdown]
# 4) Labels: categories

# %%
# get category labels
labels = os.listdir(root)

#remove ".DS_Store"
labels.remove(".DS_Store")

# %% [markdown]
# 5) Retrieve label and image information in dictionary for every image -> list of dictionaries

# %%
# get list of dictionaries with respective label and image number for all images
data = []

for label in labels:
  folder_path = root + label
  shapes = os.listdir(folder_path)
  for shape in shapes:
    category_dict = {'label': label, 'image': shape}
    data.append(category_dict)

# %% [markdown]
# 6) Retireve image directory

# %%
# function to get image directory
def image_direct(root, category_dict_item):
  return root + category_dict_item['label'] + "/" + category_dict_item['image']

# get image directories
img_dir = []
for image in data:
  direct = image_direct(root, image)
  img_dir.append(direct)

# %% [markdown]
# 8) Append image directory and size to dictionary

# %%
# add img_dir and img_size to data
for img in data:
  for dir in img_dir:
    img['img_dir'] = dir

# %% [markdown]
# ** Compute random positions -> random

# %%
# height, width combinations
combinations = []
for left_and_right in range(-22,23):
    for up_and_down in range(-22,23):
        combinations.append((left_and_right, up_and_down))

# margins
left = 22
right = 22
top = 22
bottom = 22

# make combinations for left, top, right and bottom
i = 0
new_combinations = []
for position in combinations:
  left_new = left - position[0]
  right_new = right + position[0]
  top_new = top + position[1]
  bottom_new = bottom - position[1]
  new_combinations.append([left_new, top_new, right_new, bottom_new])

# random positions
positions = []
for i in new_combinations:
  pd.Series([1, 2, 3])
  j = pd.Series(i)
  jj = j.to_list()
  positions.append(jj)

# %% [markdown]
# ** Segment foreground and background to apply ColorJitter transformation separetly

# %%
class ImageProcessor:
    def __init__(self, brightness=0.5, contrast=0.5, saturation=0.5, hue=0.1, texture_transform=None):
        self.color_jitter = transforms.ColorJitter(
            brightness=brightness,
            contrast=contrast,
            saturation=saturation,
            hue=hue
        )
        self.texture_transform = texture_transform

    def separate_foreground_background(self, image_np):
        gray = cv2.cvtColor(image_np, cv2.COLOR_RGB2GRAY)
        _, mask = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
        mask_inv = cv2.bitwise_not(mask)
        mask_3c = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
        mask_inv_3c = cv2.cvtColor(mask_inv, cv2.COLOR_GRAY2BGR)
        foreground = cv2.bitwise_and(image_np, mask_3c)
        background = cv2.bitwise_and(image_np, mask_inv_3c)
        return foreground, background, mask, mask_inv

    def apply_transform(self, image_np):
        image_pil = Image.fromarray(image_np)
        transformed_image = self.color_jitter(image_pil)
        return np.array(transformed_image)

    def combine_images(self, foreground, background, mask, mask_inv):
        # Use the mask to combine the transformed foreground and background
        combined_image = cv2.bitwise_and(foreground, foreground, mask=mask)
        combined_image += cv2.bitwise_and(background, background, mask=mask_inv)
        return combined_image

    def process_image(self, image_tensor):
        image_np = image_tensor.permute(1, 2, 0).cpu().numpy()  # Convert to numpy array in HWC format
        image_np = (image_np * 255).astype(np.uint8)  # Convert to uint8 range [0, 255]

        foreground, background, mask, mask_inv = self.separate_foreground_background(image_np)
        transformed_foreground = self.apply_transform(foreground)
        transformed_background = self.apply_transform(background)
        if self.texture_transform:
          transformed_background = self.texture_transform(transformed_background)
        combined_image = self.combine_images(transformed_foreground, transformed_background, mask, mask_inv)
        combined_image = combined_image.astype(np.float32) / 255.0  # Normalize back to [0, 1] range
        combined_image = torch.from_numpy(combined_image).permute(2, 0, 1)  # Convert back to tensor in CHW format
        return combined_image

# %%
import cv2
import random
import numpy as np

class RandomTextureTransform:
    def __init__(self, texture_paths, output_size=(224, 224)):
        self.texture_paths = texture_paths
        self.output_size = output_size

    def __call__(self, image):
        # Load a random texture image
        texture_path = random.choice(self.texture_paths)
        texture = cv2.imread(texture_path)
        texture = cv2.resize(texture, self.output_size)

        # Blend the texture with the original image using alpha blending
        alpha = 0.5  # You can adjust the alpha value to control the blending ratio
        blended = cv2.addWeighted(image, alpha, texture, 1 - alpha, 0)

        return blended

# %%
# Define your texture image paths
PATH_tex = '/content/drive/MyDrive/Thesis/Neural_network/Pre-training on Animals shapes/textures/'
textures = [
    'brick.png',
    'wood.png',
    'fabric.png',
    'grass.png',
    'metal.png',
    'marbel.png',
    'carpet.png',
    'circles.png',
    'ice.png'
]

textures_dir = []
for i in textures:
  texture_path = PATH_tex + i
  textures_dir.append(texture_path)

# %%
# Create the texture transformation
texture_transform = RandomTextureTransform(textures_dir)

# %% [markdown]
# 9) Class ShapeImagesDataset
#
# Requires:
# - data (list of dictionnaries)
# - img_dir (list of image directiories)
# - labels (list of labels)
# - transforms (preprocessing transformations)
# - image_processor (function to apply ColorJitter to foreground and background)
#
# Output:
# This class returns 2 images, 50% of the times wihtin the same category and 50% from other category
# - img1 = tensor img1
# - img2 - tensor img2
# - gt = ground truth (same category 1 or different 0)

# %%
class ShapeImageDataset (Dataset):
  # return two images, with 50% chance in same or different category and ground truth

  # __init__
  def __init__(self, data, img_dir, labels, transform=None, image_processor=None):
    self.img_labels = data
    self.img_dir = img_dir
    self.labels = labels
    self.transform = transform
    self.image_processor = image_processor
    self.same_category = [1, 0]

  # __len__
  def __len__(self):
    return len(self.img_labels)

  ### funtions for __getitem__ ###

  # we start by picking another category as the current image
  def pick_other_category(self, label):
    other_categories = []

    for cat in self.labels:
      if cat != label:
        other_categories.append(cat)

    return choice(other_categories)

  # we select an image from the other category
  def select_random_image(self, label):
    result = []
    for item in self.img_labels:
      if item["label"] == label:
        result.append(item)
    return choice(result)

  # function to read both images
  def read_image_from_directory(self, category_dict_item):
    return read_image(image_direct(root, category_dict_item), ImageReadMode.RGB)

  # __getitem__
  def __getitem__(self, idx):
    # image 1
    img1_data = self.img_labels[idx]
    img1_label = img1_data["label"]

    # 50-50 choose image 2 from same category
    same = choice(self.same_category)
    if same == 1:
      img2_label = img1_label
    else:
      img2_label = self.pick_other_category(img1_label)

    # image 2
    img2_data = self.select_random_image(img2_label)

    #gt
    if img1_label == img2_label:
      gt = 1
    else:
      gt = 0

    img1 = self.read_image_from_directory(img1_data)
    img2 = self.read_image_from_directory(img2_data)

    # apply padding
    padding_img1 = Pad(padding = choice(positions), fill=128)
    padding_img2 = Pad(padding = choice(positions), fill=128)
    img1 = padding_img1(img1)
    img2 = padding_img2(img2)

    if self.transform:
      img1 = self.transform(img1)
      img2 = self.transform(img2)

    if self.image_processor:
      img1 = self.image_processor.process_image(img1)
      img2 = self.image_processor.process_image(img2)

    return img1, img2, gt

# %%
preprocess = v2.Compose(
    [   v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ]
)

image_processor = ImageProcessor(brightness=(0.8,2), contrast=(0.6,1), saturation=0.2, hue=0.5, texture_transform = texture_transform)

# %% [markdown]
# 11) Creating dataset (len=2000)

# %%
pretraining_dataset = ShapeImageDataset(data, img_dir, labels, preprocess, image_processor)
len(pretraining_dataset)
# Out:
# 2000

# %%
pretraining_dataset[100]
# Out:
# (tensor([[[0.1294, 0.1294, 0.1294,  ..., 0.1294, 0.1294, 0.1294],
#           [0.1294, 0.1294, 0.1294,  ..., 0.1294, 0.1294, 0.1294],
#           [0.1294, 0.1294, 0.1294,  ..., 0.1294, 0.1294, 0.1294],
#           ...,
#           [0.1294, 0.1294, 0.1294,  ..., 0.1294, 0.1294, 0.1294],
#           [0.1294, 0.1294, 0.1294,  ..., 0.1294, 0.1294, 0.1294],
#           [0.1294, 0.1294, 0.1294,  ..., 0.1294, 0.1294, 0.1294]],
#
#          [[0.1569, 0.1569, 0.1569,  ..., 0.1569, 0.1569, 0.1569],
#           [0.1569, 0.1569, 0.1569,  ..., 0.1569, 0.1569, 0.1569],
#           [0.1569, 0.1569, 0.1569,  ..., 0.1569, 0.1569, 0.1569],
#           ...,
#           [0.1569, 0.1569, 0.1569,  ..., 0.1569, 0.1569, 0.1569],
#           [0.1569, 0.1569, 0.1569,  ..., 0.1569, 0.1569, 0.1569],
#           [0.1569, 0.1569, 0.1569,  ..., 0.1569, 0.1569, 0.1569]],
#
#          [[0.7373, 0.7373, 0.7373,  ..., 0.7373, 0.7373, 0.7373],
#           [0.7373, 0.7373, 0.7373,  ..., 0.7373, 0.7373, 0.7373],
#           [0.7373, 0.7373, 0.7373,  ..., 0.7373, 0.7373, 0.7373],
#           ...,
#           [0.7373, 0.7373, 0.7373,  ..., 0.7373, 0.7373, 0.7373],
#           [0.7373, 0.7373, 0.7373,  ..., 0.7373, 0.7373, 0.7373],
#           [0.7373, 0.7373, 0.7373,  ..., 0.7373, 0.7373, 0.7373]]]),
#  tensor([[[0.2667, 0.2667, 0.2667,  ..., 0.2667, 0.2667, 0.2667],
#           [0.2667, 0.2667, 0.2667,  ..., 0.2667, 0.2667, 0.2667],
#           [0.2667, 0.2667, 0.2667,  ..., 0.2667, 0.2667, 0.2667],
#           ...,
#           [0.2667, 0.2667, 0.2667,  ..., 0.2667, 0.2667, 0.2667],
#           [0.2667, 0.2667, 0.2667,  ..., 0.2667, 0.2667, 0.2667],
#           [0.2667, 0.2667, 0.2667,  ..., 0.2667, 0.2667, 0.2667]],
#
#          [[0.3647, 0.3647, 0.3647,  ..., 0.3647, 0.3647, 0.3647],
#           [0.3647, 0.3647, 0.3647,  ..., 0.3647, 0.3647, 0.3647],
#           [0.3647, 0.3647, 0.3647,  ..., 0.3647, 0.3647, 0.3647],
#           ...,
#           [0.3647, 0.3647, 0.3647,  ..., 0.3647, 0.3647, 0.3647],
#           [0.3647, 0.3647, 0.3647,  ..., 0.3647, 0.3647, 0.3647],
#           [0.3647, 0.3647, 0.3647,  ..., 0.3647, 0.3647, 0.3647]],
#
#          [[0.1647, 0.1647, 0.1647,  ..., 0.1647, 0.1647, 0.1647],
#           [0.1647, 0.1647, 0.1647,  ..., 0.1647, 0.1647, 0.1647],
#           [0.1647, 0.1647, 0.1647,  ..., 0.1647, 0.1647, 0.1647],
#           ...,
#           [0.1647, 0.1647, 0.1647,  ..., 0.1647, 0.1647, 0.1647],
#           [0.1647, 0.1647, 0.1647,  ..., 0.1647, 0.1647, 0.1647],
#           [0.1647, 0.1647, 0.1647,  ..., 0.1647, 0.1647, 0.1647]]]),
#  1)

# %% [markdown]
# Plotting

# %%
dic = '/content/drive/MyDrive/Thesis/Neural_network/Pre-training on Animals shapes/fine-tuned models/'

# %%
def tensor_to_pil(image_tensor):
    return transform.to_pil_image(image_tensor)

# %%
# Example usage to display 5 pairs of images
fig, axs = plt.subplots(4, 2, figsize=(5, 10))

for i in range(4):
    idx = np.random.randint(0, len(pretraining_dataset) - 1)
    img1, img2, gt = pretraining_dataset[idx]  # Get image pair and ground truth
    img1_pil = tensor_to_pil(img1)
    img2_pil = tensor_to_pil(img2)

    axs[i, 0].imshow(img1_pil)
    axs[i, 0].set_title('Image 1')
    axs[i, 0].axis('off')

    axs[i, 1].imshow(img2_pil)
    axs[i, 1].set_title(f'Image 2 - GT: {gt}')
    axs[i, 1].axis('off')

plt.tight_layout()
#plt.savefig(dic + 'colortexurejitter6.pdf')
plt.show()

# %% [markdown]
# 10) network

# %%
# experiment-dependent function to process an epoch of data
epoch_fun = osculari.paradigms.forced_choice.epoch_loop

# %%
dataset_loader = DataLoader(pretraining_dataset, 64)

# %%
lr = 0.01

# %%
#################################
# ResNet50: layer0, No pooling
#################################
#network
architecture = 'resnet50'        # network's architecture
weights = 'resnet50'             # the pretrained weights
img_size = 224                   # network's input size
layer = 'block0'                    # the readout layer
pooling = None                   # pooling
readout_kwargs = {               # parameters for extracting features from the pretrained network
    'architecture': architecture,
    'weights': weights,
    'layers': layer,
    'img_size': img_size,
    'pooling': pooling
}
resnet_model = osculari.models.paradigm_2afc_merge_concatenate(**readout_kwargs)

params_to_optimize = [{'params': [p for p in resnet_model.fc.parameters()]}]
optimiser = torch.optim.SGD(params_to_optimize, lr=lr, momentum=0.9, weight_decay=1e-4)

# calling the generic train_linear_probe function
training_log = osculari.paradigms.paradigm_utils.train_linear_probe(
    resnet_model, dataset_loader, epoch_fun, 'my_data/osculari_test/', device="cuda",
    epochs = 10,
    optimiser=optimiser
    )
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 193MB/s]
# [000] accuracy=0.508 loss=56540.292
# [001] accuracy=0.497 loss=39431.495
# [002] accuracy=0.496 loss=35715.081
# [003] accuracy=0.494 loss=90386.286
# [004] accuracy=0.497 loss=102690.718
# [005] accuracy=0.497 loss=9535.109
# [006] accuracy=0.492 loss=5598.536
# [007] accuracy=0.487 loss=6103.444
# [008] accuracy=0.491 loss=3822.449
# [009] accuracy=0.503 loss=4065.013

# %%
# save model's weigths
PATH = dic + 'Tex_resnet_animal_layer0_NP.pt'
torch.save(resnet_model.state_dict(), PATH)

# %%
#################################
# CLIP(ResNet50): layer0, No pooling
#################################
#network
architecture = 'clip_RN50'        # network's architecture
weights = 'clip_RN50'             # the pretrained weights
img_size = 224                   # network's input size
layer = 'block0'                    # the readout layer
pooling = None                   # pooling
readout_kwargs = {               # parameters for extracting features from the pretrained network
    'architecture': architecture,
    'weights': weights,
    'layers': layer,
    'img_size': img_size,
    'pooling': pooling
}
clip_model = osculari.models.paradigm_2afc_merge_concatenate(**readout_kwargs)

params_to_optimize = [{'params': [p for p in clip_model.fc.parameters()]}]
optimiser = torch.optim.SGD(params_to_optimize, lr=lr, momentum=0.9, weight_decay=1e-4)

# calling the generic train_linear_probe function
training_log = osculari.paradigms.paradigm_utils.train_linear_probe(
    clip_model, dataset_loader, epoch_fun, 'my_data/osculari_test/', device="cuda",
    epochs = 10,
    optimiser=optimiser
    )
# Out:
# 100%|███████████████████████████████████████| 244M/244M [00:04<00:00, 53.2MiB/s]
# [000] accuracy=0.519 loss=2024.518
# [001] accuracy=0.497 loss=4604.616
# [002] accuracy=0.490 loss=5826.848
# [003] accuracy=0.504 loss=4748.045
# [004] accuracy=0.490 loss=5064.734
# [005] accuracy=0.516 loss=2454.501
# [006] accuracy=0.500 loss=858.766
# [007] accuracy=0.489 loss=452.384
# [008] accuracy=0.504 loss=244.883
# [009] accuracy=0.483 loss=256.093

# %%
# save model's weigths
PATH = dic + 'Tex_clip_animal_layer0_NP.pt'
torch.save(clip_model.state_dict(), PATH)

# %%
#################################
# CLIP(ViT): layer0, No pooling
#################################
#network
architecture = 'clip_ViT-B/32'        # network's architecture
weights = 'clip_ViT-B/32'             # the pretrained weights
img_size = 224                   # network's input size
layer = 'block0'                    # the readout layer
pooling = None                   # pooling
readout_kwargs = {               # parameters for extracting features from the pretrained network
    'architecture': architecture,
    'weights': weights,
    'layers': layer,
    'img_size': img_size,
    'pooling': pooling
}
clipViT_model = osculari.models.paradigm_2afc_merge_concatenate(**readout_kwargs)

params_to_optimize = [{'params': [p for p in clipViT_model.fc.parameters()]}]
optimiser = torch.optim.SGD(params_to_optimize, lr=lr, momentum=0.9, weight_decay=1e-4)

# calling the generic train_linear_probe function
training_log = osculari.paradigms.paradigm_utils.train_linear_probe(
    clipViT_model, dataset_loader, epoch_fun, 'my_data/osculari_test/', device="cuda",
    epochs = 10,
    optimiser=optimiser
    )
# Out:
# 100%|███████████████████████████████████████| 338M/338M [00:04<00:00, 86.5MiB/s]
# [000] accuracy=0.482 loss=5.749
# [001] accuracy=0.501 loss=6.516
# [002] accuracy=0.499 loss=2.956
# [003] accuracy=0.486 loss=3.163
# [004] accuracy=0.493 loss=3.154
# [005] accuracy=0.506 loss=3.533
# [006] accuracy=0.498 loss=1.151
# [007] accuracy=0.516 loss=1.054
# [008] accuracy=0.495 loss=0.902
# [009] accuracy=0.506 loss=0.886

# %%
# save model's weigths
PATH = dic + 'Tex_clipViT_animal_layer0_NP.pt'
torch.save(clipViT_model.state_dict(), PATH)
